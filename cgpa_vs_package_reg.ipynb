# %% [markdown]
# <a href="https://colab.research.google.com/github/Antony359/ML_projects/blob/main/cgpa_vs_package_reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/placement.csv')
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.tail()
# Out:
#      cgpa  package
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33

# %%
df.isna().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
df.dtypes
# Out:
# cgpa       float64
# package    float64
# dtype: object

# %%
x=df.iloc[:,:-1]
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color='m')
plt.xlabel('CGPA',color='b')
plt.ylabel('PACKAGE',color='g')
plt.title('CGPA_VS_PACKAGE',color='r')
plt.grid()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)
x_train
# Out:
#      cgpa
# 131  6.37
# 96   7.11
# 181  8.22
# 19   7.48
# 153  7.94
# ..    ...
# 67   6.51
# 192  8.25
# 117  7.12
# 47   5.84
# 172  6.93
#
# [140 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([2.98741886, 2.56299265, 2.62783555, 3.4295295 , 3.07584099,
#        2.36256917, 3.54742567, 2.47457053, 4.16638056, 3.24089563,
#        2.12677683, 3.2173164 , 2.54530823, 3.06994618, 3.39416065,
#        2.8754175 , 2.63962516, 2.83415384, 2.37435878, 2.93436559,
#        3.18784235, 2.33898993, 3.53563605, 4.03079997, 2.20340934,
#        1.9027741 , 3.10531503, 2.61604593, 1.91456372, 1.8968793 ,
#        2.92847078, 3.73016473, 2.61015112, 2.09140798, 2.51583419,
#        3.67711146, 3.19373716, 2.98741886, 3.87164014, 2.50993938,
#        3.14068389, 1.90866891, 3.79500763, 2.98741886, 3.99543112,
#        4.29606635, 2.48636014, 3.00510329, 3.25858005, 1.75540389,
#        3.29984371, 2.46867572, 3.54153086, 2.42151725, 3.7773232 ,
#        2.74573172, 3.23500082, 3.09942023, 4.42575213, 2.33898993])

# %%
plt.scatter(x_train,y_train,color='b')
plt.plot(x_test,y_pred,color='r')

# %%
print(model.predict([[8]]))
# Out:
# [3.61226856]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df1=pd.DataFrame({'Actual value':y_test,'predicted value':y_pred})
df1
# Out:
#      Actual value  predicted value
# 18           2.98         2.987419
# 170          2.87         2.562993
# 107          2.59         2.627836
# 98           3.83         3.429530
# 177          3.64         3.075841
# 182          2.08         2.362569
# 5            2.99         3.547426
# 146          2.46         2.474571
# 12           3.65         4.166381
# 152          3.08         3.240896
# 61           1.61         2.126777
# 125          3.16         3.217316
# 180          2.72         2.545308
# 154          2.85         3.069946
# 80           3.44         3.394161
# 7            2.48         2.875418
# 33           2.73         2.639625
# 130          2.49         2.834154
# 37           2.43         2.374359
# 74           3.44         2.934366
# 183          2.72         3.187842
# 145          2.18         2.338990
# 45           3.58         3.535636
# 159          4.08         4.030800
# 60           2.19         2.203409
# 123          2.30         1.902774
# ...

# %%
print('slope is',model.coef_)
# Out:
# slope is [0.58948085]

# %%
print('constant is',model.intercept_)
# Out:
# constant is -1.1035782225186654

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score
print('error is',mean_absolute_percentage_error(y_test,y_pred))
print('error is',r2_score(y_test,y_pred))
# Out:
# error is 0.09414152629774195
# error is 0.7509091646328012
