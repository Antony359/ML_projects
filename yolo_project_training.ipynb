# %% [markdown]
# <a href="https://colab.research.google.com/github/Antony359/ML_projects/blob/main/yolo_project_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#cloning the darknet
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15851, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15851 (delta 5), reused 11 (delta 4), pack-reused 15833 (from 1)
# Receiving objects: 100% (15851/15851), 14.42 MiB | 9.89 MiB/s, done.
# Resolving deltas: 100% (10671/10671), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
#check cuda version
! /usr/local/cuda/bin/nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
#buiding
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
# ...

# %%
# !pwd
# Out:
# /content/darknet

# %%
#mounting the g-drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#copy zip file into root directory of colab
# !cp /content/drive/MyDrive/project_fitness_reg/obj.zip ../

# %%
#unzip the dataset and move to inside data directory
# !unzip ../obj.zip -d data/
# Out:
# Archive:  ../obj.zip
#   inflating: data/obj/catch (1).jpg
#   inflating: data/obj/catch (1).txt
#   inflating: data/obj/catch (2).jpg
#   inflating: data/obj/catch (2).txt
#   inflating: data/obj/catch (3).jpg
#   inflating: data/obj/catch (3).txt
#   inflating: data/obj/catch (4).jpg
#   inflating: data/obj/catch (4).txt
#   inflating: data/obj/catch (5).jpg
#   inflating: data/obj/catch (5).txt
#   inflating: data/obj/catch (6).jpg
#   inflating: data/obj/catch (6).txt
#   inflating: data/obj/catch (7).jpg
#   inflating: data/obj/catch (7).txt
#   inflating: data/obj/catch (8).jpg
#   inflating: data/obj/catch (8).txt
#   inflating: data/obj/catch(10).jpg
#   inflating: data/obj/catch(10).txt
#   inflating: data/obj/catch(11).jpg
#   inflating: data/obj/catch(11).txt
#   inflating: data/obj/catch(12).jpg
#   inflating: data/obj/catch(12).txt
#   inflating: data/obj/catch(13).jpg
#   inflating: data/obj/catch(13).txt
#   inflating: data/obj/catch(14).jpg
# ...

# %%
#copy obj.data file from drive to data folder
# !cp /content/drive/MyDrive/project_fitness_reg/obj.data ./data

# %%
#copy obj.names file from drive to  data folder
# !cp /content/drive/MyDrive/project_fitness_reg/obj.names ./data

# %%
#copy config file from drive to  data folder
# !cp /content/drive/MyDrive/project_fitness_reg/yolov3_custom.cfg ./data

# %%
#copy obj.data file from drive to  darknet
# !cp /content/drive/MyDrive/project_fitness_reg/generate_train.py ./

# %%
#run generate file
# !python generate_train.py

# %%
#download pretrained weight
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2024-08-18 07:24:13--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  14.2MB/s    in 12s
#
# 2024-08-18 07:24:26 (13.4 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# run training
# !./darknet detector train data/obj.data data/yolov3_custom.cfg /content/drive/MyDrive/project_fitness_reg/backup/yolov3_custom_last.weights -dont_show
# Out:
#  CUDA-version: 12020 (12020), cuDNN: 8.9.6, GPU count: 1
#  OpenCV version: 4.5.4
# valid: Using default 'data/train.txt'
# yolov3_custom
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
# !./darknet detector demo /content/drive/MyDrive/project_fitness_reg/obj.data \
/content/drive/MyDrive/project_fitness_reg/yolov3_custom.cfg \
/content/drive/MyDrive/project_fitness_reg/backup/yolov3_custom_last.weights \
/content/drive/MyDrive/project_fitness_reg/pullups.mp4 \
-out_filename /content/drive/MyDrive/project_fitness_reg/webcam_output.mp4
# Out:
#  CUDA-version: 12020 (12020), cuDNN: 8.9.6, GPU count: 1
#  OpenCV version: 4.5.4
# Demo
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
